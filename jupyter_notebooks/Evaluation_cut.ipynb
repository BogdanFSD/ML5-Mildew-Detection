# %% [markdown]
# **Modeling and Evaluation**

# %% [markdown]
# ### Objectives

# %% [markdown]
# * Business requirements 2:
# - The client is interested in predicting if a cherry leaf is healthy or contains powdery mildew

# %% [markdown]
# ### Inputs

# %% [markdown]
# * Data from test, train validation folders
# * Image shape

# %% [markdown]
# ### Outputs

# %% [markdown]
# * Image augmentation
# * Model creation
# * Model training
# * Save model
# * Learning curve
# * Model Evaluation
# * Matrix
# * Save evaluation
# * Check prediction on new file

# %% [markdown]
# ### Import

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.image import imread
import joblib

# %% [markdown]
# ### Set working directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/workspace/ML5-Mildew-Detection/jupyter_notebooks'

# %%
os.chdir('/workspace/ML5-Mildew-Detection')
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Double check directory set correctly

# %%
working_dir = os.getcwd()
working_dir
# Out:
# '/workspace/ML5-Mildew-Detection'

# %% [markdown]
# ## Setting input directories

# %%
my_data_dir = 'inputs/cherryleaves_data/cherry-leaves/cut/cherry-leaves'
training_path = my_data_dir + '/train' 
validation_path = my_data_dir + '/validation'
test_path = my_data_dir + '/test'

# %% [markdown]
# ## Setting output directory

# %%
version = 'v2_cut'
file_path = f'outputs/{version}'

if 'outputs' in os.listdir(working_dir) and version in os.listdir(working_dir + '/outputs'):
    print('Old version is already available create a new version.')
    pass
else:
    os.makedirs(name=file_path)
# Out:
# Old version is already available create a new version.

# %% [markdown]
# ---

# %% [markdown]
# ## Set labels

# %%
labels = os.listdir(training_path)
print('Label for the images are', labels)
# Out:
# Label for the images are ['powdery_mildew_cut', 'healthy_cut']

# %% [markdown]
# ### Image shape

# %%
version = 'v2_cut'
image_shape = joblib.load(filename=f"outputs/{version}/image_shape.pkl")
image_shape
# Out:
# (85, 256, 3)

# %% [markdown]
# Count number images in each folder

# %%
import plotly.express as px

df_freq = pd.DataFrame([])
for folder in ['train', 'test', 'validation']:
    for label in labels:
        df_freq = df_freq.append(
            pd.Series(data={'Set': folder,
                            'Label': label,
                            'Count': int(len(os.listdir(my_data_dir + '/' + folder + '/' + label)))}
                      ),
            ignore_index=True
        )

        print(
            f"* {folder} - {label}: {len(os.listdir(my_data_dir+'/'+ folder + '/' + label))} images")

print("\n")
# Out:
# * train - powdery_mildew_cut: 4418 images
# * train - healthy_cut: 4418 images
# * test - powdery_mildew_cut: 1263 images
# * test - healthy_cut: 1263 images
# * validation - powdery_mildew_cut: 631 images
# * validation - healthy_cut: 631 images

# %% [markdown]
# Label Distribution

# %%
fig = px.bar(df_freq, 
            x="Set", 
            y="Count", 
            color='Label', 
            title="Cherry Leaves Dataset",
            barmode="group",
            text="Label")
fig.update_layout(
    autosize=False,
    width=900, 
    height=600, 
    )
fig.show()
fig.write_image(f'{file_path}/label_distribution.png')

df_freq_pie = df_freq.groupby('Set')['Count'].sum().reset_index()

fig = go.Figure(data=[go.Pie(
    labels=df_freq_pie['Set'], 
    values=df_freq_pie['Count'],
    hole=0.5,
    marker=dict(colors=['#EF553B', '#636EFA', '#00CC96'])
)])

fig.update_layout(
    title_text='Cherry Leaves Dataset',
    width=800, 
    height=600,
    annotations=[dict(text='Set', x=0.5, y=0.5, font_size=20, showarrow=False)]
)
fig.write_image(f'{file_path}/label_distribution_pie.png')
fig.show()
# Out:
# <div>                            <div id="8c70080f-2dbb-48a3-885a-0dae71cda262" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c70080f-2dbb-48a3-885a-0dae71cda262")) {                    Plotly.newPlot(                        "8c70080f-2dbb-48a3-885a-0dae71cda262",                        [{"alignmentgroup": "True", "hovertemplate": "Label=%{text}<br>Set=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "powdery_mildew_cut", "marker": {"color": "#636efa"}, "name": "powdery_mildew_cut", "offsetgroup": "powdery_mildew_cut", "orientation": "v", "showlegend": true, "text": ["powdery_mildew_cut", "powdery_mildew_cut", "powdery_mildew_cut"], "textposition": "auto", "type": "bar", "x": ["train", "test", "validation"], "xaxis": "x", "y": [4418.0, 1263.0, 631.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Label=%{text}<br>Set=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "healthy_cut", "marker": {"color": "#EF553B"}, "name": "healthy_cut", "offsetgroup": "healthy_cut", "orientation": "v", "showlegend": true, "text": ["healthy_cut", "healthy_cut", "healthy_cut"], "textposition": "auto", "type": "bar", "x": ["train", "test", "validation"], "xaxis": "x", "y": [4418.0, 1263.0, 631.0], "yaxis": "y"}],                        {"autosize": false, "barmode": "group", "height": 600, "legend": {"title": {"text": "Label"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca2 ...
# <div>                            <div id="3e41ef3b-5846-48f8-99dd-a872d5766e9b" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e41ef3b-5846-48f8-99dd-a872d5766e9b")) {                    Plotly.newPlot(                        "3e41ef3b-5846-48f8-99dd-a872d5766e9b",                        [{"hole": 0.5, "labels": ["test", "train", "validation"], "marker": {"colors": ["#EF553B", "#636EFA", "#00CC96"]}, "type": "pie", "values": [2526.0, 8836.0, 1262.0]}],                        {"annotations": [{"font": {"size": 20}, "showarrow": false, "text": "Set", "x": 0.5, "y": 0.5}], "height": 600, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}] ...

# %% [markdown]
# ---

# %% [markdown]
# Something to make in unique

# %% [markdown]
# ## Image data augmentation

# %% [markdown]
# import ImageDataGenerator

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Intiatize ImageDataGenerator

# %%
augmented_image_data = ImageDataGenerator(rotation_range=20,
                                   width_shift_range=0.10, 
                                   height_shift_range=0.10,
                                   shear_range=0.1,
                                   zoom_range=0.1,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest',
                                   rescale=1./255
                              )

# %% [markdown]
# ### Batch size

# %%
batch_size = 64

# %% [markdown]
# ### Augment training image set

# %%
train_set = augmented_image_data.flow_from_directory(training_path,
                                                     target_size=image_shape[:2],
                                                     color_mode='rgb',
                                                     batch_size=batch_size,
                                                     class_mode='categorical',
                                                     shuffle=True
                                                     )

train_set.class_indices
# class_names_str = ", ".join(train_set.class_indices)

# print(f"Classes: {class_names_str}")
# Out:
# Found 8836 images belonging to 2 classes.
# {'healthy_cut': 0, 'powdery_mildew_cut': 1}

# %% [markdown]
# ### Augment Validation Dataset Images

# %%
validation_set = ImageDataGenerator(rescale=1./255).flow_from_directory(validation_path,
                                                          target_size=image_shape[:2],
                                                          color_mode='rgb',
                                                          batch_size=batch_size,
                                                          class_mode='categorical',
                                                          shuffle=False
                                                          )

validation_set.class_indices
class_names_str_1 = ", ".join(validation_set.class_indices)
print(f"Classes: {class_names_str_1}")
# Out:
# Found 1262 images belonging to 2 classes.
# Classes: healthy_cut, powdery_mildew_cut

# %% [markdown]
# ### Augment Test Dataset Images

# %%
test_set = ImageDataGenerator(rescale=1./255).flow_from_directory(test_path,
                                                    target_size=image_shape[:2],
                                                    color_mode='rgb',
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False
                                                    )

test_set.class_indices
class_names_str_2 = ", ".join(test_set.class_indices)
print(f"Classes: {class_names_str_2}")
# Out:
# Found 2526 images belonging to 2 classes.
# Classes: healthy_cut, powdery_mildew_cut

# %% [markdown]
# ### Plot augmented test images

# %%
for _ in range(3):
    img, label = test_set.next()
    img_class = list(test_set.class_indices.keys())[np.argmax(label)]
    print(img.shape)   #  (1,256,256,3)
    plt.imshow(img[0])
    plt.title(img_class)
    plt.show()
# Out:
# (64, 85, 256, 3)
# (64, 85, 256, 3)
# (64, 85, 256, 3)

# %% [markdown]
# ### Plot augmented training image set

# %%
for _ in range(3):
    img, label = train_set.next()
    img_class = list(train_set.class_indices.keys())[np.argmax(label)]
    print(img.shape)   #  (1,256,256,3)
    plt.imshow(img[0])
    plt.title(img_class)
    plt.show()
# Out:
# (32, 85, 256, 3)
# (32, 85, 256, 3)
# (32, 85, 256, 3)

# %% [markdown]
# ### Augment validation image set

# %%
for _ in range(3):
    img, label = validation_set.next()
    img_class = list(validation_set.class_indices.keys())[np.argmax(label)]
    print(img.shape)   #  (1,256,256,3)
    plt.imshow(img[0])
    plt.title(img_class)
    plt.show()
# Out:
# (32, 85, 256, 3)
# (32, 85, 256, 3)
# (32, 85, 256, 3)

# %% [markdown]
# ### Save class_indices

# %%
joblib.dump(value=train_set.class_indices,
            filename=f"{file_path}/class_indices_1.pkl")
# Out:
# ['outputs/v2_softmax/class_indices_1.pkl']

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ### Import model packages

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.activations import swish
from tensorflow.keras.initializers import lecun_normal
import tensorflow as tf
def mish(x):
    return x * tf.math.tanh(tf.math.softplus(x))

# %% [markdown]
# ## Model

# %%
def create_tf_model():
    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(3, 3),
              input_shape=image_shape, activation=mish, ))
    model.add(MaxPooling2D(pool_size=(2, 2)))



    model.add(Conv2D(filters=64, kernel_size=(3, 3),
              input_shape=image_shape, activation=mish, ))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=64, kernel_size=(3, 3),
              input_shape=image_shape, activation=mish, ))
    model.add(MaxPooling2D(pool_size=(2, 2)))



    model.add(Flatten())
    model.add(Dense(128, activation=mish))
    model.add(Dropout(0.5))


    model.add(Dense(2, activation='softmax'))

    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

    return model

# %% [markdown]
# ### Model Summary

# %%
create_tf_model().summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_17 (Conv2D)           (None, 83, 254, 32)       896
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 41, 127, 32)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 39, 125, 64)       18496
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 19, 62, 64)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 17, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 8, 30, 64)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 15360)             0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               1966208
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 2,022,786
# Trainable params: 2,022,786
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Early Stopping

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=5)

# %% [markdown]
# ### Fit model for training

# %%
model = create_tf_model()
model.fit(train_set,
          epochs=10,
          steps_per_epoch=len(train_set.classes) // batch_size,
          validation_data=validation_set,
          callbacks=[early_stop],
          verbose=1
          )
# Out:
# Epoch 1/10
# 138/138 [==============================] - 413s 3s/step - loss: 0.3508 - accuracy: 0.8461 - val_loss: 0.3815 - val_accuracy: 0.8487
# Epoch 2/10
# 138/138 [==============================] - 343s 2s/step - loss: 0.1442 - accuracy: 0.9539 - val_loss: 0.1379 - val_accuracy: 0.9683
# Epoch 3/10
# 138/138 [==============================] - 345s 3s/step - loss: 0.1101 - accuracy: 0.9640 - val_loss: 0.1561 - val_accuracy: 0.9493
# Epoch 4/10
# 138/138 [==============================] - 364s 3s/step - loss: 0.0906 - accuracy: 0.9682 - val_loss: 0.1553 - val_accuracy: 0.9770
# Epoch 5/10
# 138/138 [==============================] - 396s 3s/step - loss: 0.0797 - accuracy: 0.9730 - val_loss: 0.1270 - val_accuracy: 0.9715
# Epoch 6/10
# 138/138 [==============================] - 335s 2s/step - loss: 0.0734 - accuracy: 0.9754 - val_loss: 0.0598 - val_accuracy: 0.9802
# Epoch 7/10
# 138/138 [==============================] - 431s 3s/step - loss: 0.0637 - accuracy: 0.9781 - val_loss: 0.0501 - val_accuracy: 0.9889
# Epoch 8/10
# 138/138 [==============================] - 327s 2s/step - loss: 0.0637 - accuracy: 0.9780 - val_loss: 0.0433 - val_accuracy: 0.9889
# Epoch 9/10
# 138/138 [==============================] - 318s 2s/step - loss: 0.1000 - accuracy: 0.9680 - val_loss: 0.0457 - val_accuracy: 0.9905
# Epoch 10/10
# 138/138 [==============================] - 373s 3s/step - loss: 0.0555 - accuracy: 0.9812 - val_loss: 0.0597 - val_accuracy: 0.9857

# %% [markdown]
# ### Save model

# %%
model.save('outputs/v1_cut/mildew_detection_softmax.h5')

# %% [markdown]
# ## Model Performance

# %% [markdown]
# ### Model learining curve

# %%
losses = pd.DataFrame(model.history.history)

sns.set_style("whitegrid")
losses[['loss', 'val_loss']].plot(style='.-')
plt.title("Loss")
plt.savefig(f'{file_path}/model_training_losses.png',
            bbox_inches='tight', dpi=150)
plt.show()

print("\n")
losses[['accuracy', 'val_accuracy']].plot(style='.-')
plt.title("Accuracy")
plt.savefig(f'{file_path}/model_training_acc.png',
            bbox_inches='tight', dpi=150)
plt.show()
sns.set_style("whitegrid")
pd.DataFrame(model.history.history).plot(figsize=(8,5))
plt.show()

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Scatter( y=model.history.history['val_loss'], name="val_loss"),
    secondary_y=False,
)

fig.add_trace(
    go.Scatter( y=model.history.history['loss'], name="loss"),
    secondary_y=False,
)

fig.add_trace(
    go.Scatter( y=model.history.history['val_accuracy'], name="val accuracy"),
    secondary_y=True,
)

fig.add_trace(
    go.Scatter( y=model.history.history['accuracy'], name="accuracy"),
    secondary_y=True,
)

# Add figure title
fig.update_layout(
    title_text="Loss/Accuracy "
)

# Set x-axis title
fig.update_xaxes(title_text="Epoch")

# Set y-axes titles
fig.update_yaxes(title_text="<b>primary</b> Loss", secondary_y=False)
fig.update_yaxes(title_text="<b>secondary</b> Accuracy", secondary_y=True)

fig.update_layout(
    autosize=False,
    width=800, 
    height=500, 
    )
fig.write_image(f'{file_path}/model_big_plot.png')
fig.show()
# Out:
# <div>                            <div id="d302c83e-311f-4e84-9faa-c662ca2d3e43" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d302c83e-311f-4e84-9faa-c662ca2d3e43")) {                    Plotly.newPlot(                        "d302c83e-311f-4e84-9faa-c662ca2d3e43",                        [{"name": "val_loss", "type": "scatter", "xaxis": "x", "y": [0.3814835548400879, 0.13786685466766357, 0.15609405934810638, 0.1553151160478592, 0.12703819572925568, 0.059836067259311676, 0.05010604485869408, 0.043311890214681625, 0.04569178819656372, 0.059680599719285965], "yaxis": "y"}, {"name": "loss", "type": "scatter", "xaxis": "x", "y": [0.3507560193538666, 0.14417129755020142, 0.11011814326047897, 0.09055039286613464, 0.0797409936785698, 0.07337263226509094, 0.06366473436355591, 0.06374125182628632, 0.0999750867486, 0.055482376366853714], "yaxis": "y"}, {"name": "val accuracy", "type": "scatter", "xaxis": "x", "y": [0.8486529588699341, 0.9683042764663696, 0.9492868185043335, 0.9770206212997437, 0.9714738726615906, 0.9801901578903198, 0.9889065027236938, 0.9889065027236938, 0.9904912710189819, 0.9857369065284729], "yaxis": "y2"}, {"name": "accuracy", "type": "scatter", "xaxis": "x", "y": [0.8461012244224548, 0.9539443850517273, 0.963976263999939, 0.9681942462921143, 0.9729822278022766, 0.9753761887550354, 0.9781121611595154, 0.9779981970787048, 0.9679662585258484, 0.9811901450157166], "yaxis": "y2"}],                        {"autosize": false, "height": 500, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d ...

# %%
from sklearn.metrics import roc_curve, auc, accuracy_score, roc_auc_score
preds = np.argmax(model.predict(test_set), axis=1)
y_pred = np.rint(preds)

y_true = test_set.labels
sns.set_style("whitegrid")
fpr, tpr, _ = roc_curve(y_true, y_pred)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(8, 5))
lw = 2
plt.plot(fpr, tpr, color='darkorange',
lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, label="Random classifier", linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.savefig(f'{file_path}/roccurve.png',
            bbox_inches='tight', dpi=150)
print('Area Under ROC-Curve: ', roc_auc_score(y_true, y_pred))
plt.show()
# Out:
# Area Under ROC-Curve:  0.986935866983373

# %%
import sklearn.metrics as metrics
from sklearn.metrics import classification_report, confusion_matrix, f1_score 
import warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    Y_pred = model.predict(test_set)
    y_pred = np.argmax(Y_pred, axis=1)
    print('Classification report')
    print(classification_report(test_set.classes, y_pred, target_names=labels))
# Out:
# Classification report
#                     precision    recall  f1-score   support
#
# powdery_mildew_cut       0.97      1.00      0.99      1263
#        healthy_cut       1.00      0.97      0.99      1263
#
#           accuracy                           0.99      2526
#          macro avg       0.99      0.99      0.99      2526
#       weighted avg       0.99      0.99      0.99      2526

# %%
cm =confusion_matrix(y_true,y_pred)

classes=list(test_set.class_indices.keys()) 
length=len(classes)
plt.figure(figsize=(8, 5))
sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
plt.xticks(np.arange(length)+.5, classes, rotation= 0, fontsize=8)
plt.yticks(np.arange(length)+.3, classes, rotation=90, fontsize=8)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.savefig(f'{file_path}/confusion_matrix.png',
            bbox_inches='tight', dpi=150)
plt.show()

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Load saved model

# %%
from keras.models import load_model

model = load_model('outputs/v1_cut/mildew_detection_softmax.h5', custom_objects={'mish': mish})

# %% [markdown]
# ### Evaluate model on test set

# %%
evaluation = model.evaluate(test_set)
# Out:
# 40/40 [==============================] - 25s 602ms/step - loss: 0.0422 - accuracy: 0.9869

# %% [markdown]
# ### Save evaluation pickle

# %%
joblib.dump(value=evaluation,
            filename=f"outputs/v2_cut/evaluation.pkl")
# Out:
# ['outputs/v1_cut/evaluation.pkl']

# %% [markdown]
# ## Predict on new data

# %% [markdown]
# ### Load random image as PIL

# %%
from tensorflow.keras.preprocessing import image

pointer = 40
label = labels[1]  # select healthy or infected leaves

pil_image = image.load_img(test_path + '/' + label + '/' + os.listdir(test_path+'/' + label)[pointer],
                           target_size=image_shape, color_mode='rgb')
print(f'Image shape: {pil_image.size}, Image mode: {pil_image.mode}')
pil_image
# Out:
# Image shape: (256, 85), Image mode: RGB
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x85>

# %% [markdown]
# ### Convert image to array and prepare for prediction

# %%
my_image = image.img_to_array(pil_image)
my_image = np.expand_dims(my_image, axis=0)/255
print(my_image.shape)
# Out:
# (1, 85, 256, 3)

# %% [markdown]
# ### Predict class probabilities

# %%
pred_proba = model.predict(my_image)[0, 0]

target_map = {v: k for k, v in train_set.class_indices.items()}
pred_class = target_map[pred_proba > 0.5]

if pred_class == target_map[0]:
    pred_proba = 1 - pred_proba

print(pred_proba)
print(pred_class)
# Out:
# 0.9999832
# powdery_mildew_cut
