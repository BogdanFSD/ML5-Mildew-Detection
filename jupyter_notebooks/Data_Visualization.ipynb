# %% [markdown]
# #  Data Visualization

# %% [markdown]
# ## Objectives
#
# Business requirement 1:
# * The client is interested in conducting a study to visually differentiate a cherry leaf that is healthy from one that contains powdery mildew.
#
# ## Inputs
#
# * Data taken from test, train, validation folders.

# %% [markdown]
# ---

# %% [markdown]
# ## Output
#
# * Plot mean and variability of images
# * Create contrast between healthy and infected leaves
# * Generate code that answers busines requirement 1 and can be used to build an image monatage on the Streamlit dashboard.

# %% [markdown]
# Change working directory

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/workspace/ML5-Mildew-Detection/jupyter_notebooks'

# %%
os.chdir('/workspace/ML5-Mildew-Detection')
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Double check directory set correctly

# %%
working_dir = os.getcwd()
working_dir
# Out:
# '/workspace/ML5-Mildew-Detection'

# %% [markdown]
# Import libraries

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
sns.set_style("white")
from matplotlib.image import imread

# %% [markdown]
# Confirm the new current directory!!!

# %% [markdown]
# ## Setting input directories

# %%
my_data_dir = 'inputs/cherryleaves_data/cherry-leaves'
training_path = my_data_dir + '/train' 
validation_path = my_data_dir + '/validation'
test_path = my_data_dir + '/test'

# %% [markdown]
# ## Setting output directory

# %%
version = 'v1'
file_path = f'outputs/{version}'

if 'outputs' in os.listdir(working_dir) and version in os.listdir(working_dir + '/outputs'):
    print('Old version is already available create a new version.')
    pass
else:
    os.makedirs(name=file_path)
# Out:
# Old version is already available create a new version.

# %% [markdown]
# ---

# %% [markdown]
# ## Set labels

# %%
labels = os.listdir(training_path)
print('Label for the images are', labels)
# Out:
# Label for the images are ['healthy', 'powdery_mildew']

# %% [markdown]
# ---

# %% [markdown]
# # Data visualization

# %% [markdown]
# ---

# %% [markdown]
# ## Image size of the image dataset

# %% [markdown]
# In order Machine learning running correctly we should process shape and size of the images so they look beter for visualizer. This would give us better results of the model.

# %%
dim1, dim2 = [], []
for label in labels:
    for image_filename in os.listdir(training_path + '/' + label):
        img = imread(training_path + '/' + label + '/' + image_filename)
        d1, d2, colors = img.shape
        dim1.append(d1)  # image height
        dim2.append(d2)  # image width

sns.set_style("whitegrid")
fig, axes = plt.subplots()
sns.scatterplot(x=dim2, y=dim1, alpha=0.2)
axes.set_xlabel("Width (pixels)")
axes.set_ylabel("Height (pixels)")
dim1_mean = int(np.array(dim1).mean())
dim2_mean = int(np.array(dim2).mean())
axes.axvline(x=dim1_mean, color='r', linestyle='--')
axes.axhline(y=dim2_mean, color='r', linestyle='--')
plt.show()
print(f"Width average: {dim2_mean} \nHeight average: {dim1_mean}")
# Out:
# Width average: 256
# Height average: 256

# %% [markdown]
# ### Images size for training the model is the average from all images in the train set.

# %%
image_shape = (dim1_mean, dim2_mean, 3)
image_shape
# Out:
# (256, 256, 3)

# %% [markdown]
# ### Save the image shape embeddings

# %%
joblib.dump(value=image_shape ,
            filename=f"{file_path}/image_shape.pkl")
# Out:
# ['outputs/v1/image_shape.pkl']

# %% [markdown]
# ---

# %% [markdown]
# ## Average and variability of images per label

# %% [markdown]
# ### Function to load images in an array (tensor)

# %%
from tensorflow.keras.preprocessing import image


def load_image_as_array(my_data_dir, new_size=(50, 50), n_images_per_label=20):

    X, y = np.array([], dtype='int'), np.array([], dtype='object')
    labels = os.listdir(my_data_dir)

    for label in labels:
        counter = 0
        for image_filename in os.listdir(my_data_dir + '/' + label):
            # n_images_per_label: we set a limit, since it may take too much time
            if counter < n_images_per_label:

                img = image.load_img(
                    my_data_dir + '/' + label + '/' + image_filename, target_size=new_size)
                if image.img_to_array(img).max() > 1:
                    img_resized = image.img_to_array(img) / 255
                else:
                    img_resized = image.img_to_array(img)

                X = np.append(X, img_resized).reshape(-1,
                                                      new_size[0], new_size[1], img_resized.shape[2])
                y = np.append(y, label)
                counter += 1

    return X, y

# %% [markdown]
# ### Load image shapes and labels in an array

# %%
X, y = load_image_as_array(my_data_dir=training_path,
                           new_size=image_shape,
                           n_images_per_label=30)
print(X.shape, y.shape)
# Out:
# (60, 256, 256, 3) (60,)

# %% [markdown]
# ### Plot and save mean and variability of images per label

# %%
def plot_mean_variability_per_labels(X, y, figsize=(8, 5), save_image=False):
    """
    The pseudo-code for the function is:
    * Loop over all labels
    * Subset an array for a given label
    * Calculate the mean and standard deviation
    * Create a figure displaying the mean and variability of images
    * Save the image
    """

    for label_to_display in np.unique(y):
        sns.set_style("white")

        y = y.reshape(-1, 1, 1)
        boolean_mask = np.any(y == label_to_display, axis=1).reshape(-1)
        arr = X[boolean_mask]

        avg_img = np.mean(arr, axis=0)
        std_img = np.std(arr, axis=0)
        print(f"==== Label {label_to_display} ====")
        print(f"Image Shape: {avg_img.shape}")
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=figsize)
        axes[0].set_title(f"Average image for label {label_to_display}")
        axes[0].imshow(avg_img, cmap='gray')
        axes[1].set_title(f"Variability image for label {label_to_display}")
        axes[1].imshow(std_img, cmap='gray')

        if save_image:
            plt.savefig(f"{file_path}/avg_var_{label_to_display}.png",
                        bbox_inches='tight', dpi=150)
        else:
            plt.tight_layout()
            plt.show()
            print("\n")

# %%
plot_mean_variability_per_labels(X=X, y=y, figsize=(10, 5), save_image=True)
# Out:
# ==== Label healthy ====
# Image Shape: (256, 256, 3)
# ==== Label powdery_mildew ====
# Image Shape: (256, 256, 3)

# %%
#import os
#try:
    # create here your folder
    # os.makedirs(name='')
#except Exception as e:
#    print(e)
# Out:
#   Cell In[12], line 5
#     except Exception as e:
#     ^
# IndentationError: expected an indented block
